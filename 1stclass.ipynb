# %% [markdown]
# ### 🔹 条件与循环逻辑
# - **涉及知识**
#   -`if-elif-else`;`for-else`;`while-else`
# - **常见错误**：
#   - `if-elif-else` 边界条件写错（如 `<=` 和 `<` 搞混）。
#   - 循环里忘记更新变量，导致死循环。
# - **典型例题**：
# 输入一个百分制成绩，要求输出成绩等级A、B、C、D、E，
#   - 其中90~100分为A，80~89分为B，70~79分为C，60~69分为D，60分以下为E。
#   - 要求：
#     用if语句实现；
#     输入百分制成绩后要判断该成绩的合理性，对不合理的成绩应输出出错信息。

# %% [markdown]
# ### 🔹 算法与逻辑思维
# - **常见错误**：
#   - 边界条件没考虑（空输入、极大值）。
#   - 时间复杂度过高（用三重循环处理字符串）。
# - **典型例题**：
#   - 双数之和

# %% [markdown]
# ### 🔹 函数与作用域
# - **常见错误**：
#   - 忘记 `return`，导致函数返回 `None`。
#   - 全局变量和局部变量混淆。
# - **典型例题**：
#   - 写一个函数计算 n 的阶乘。

# %%
nums=[2,7,11,15]
target=int(9)
nlist=[]
for i in range(len(nums)):
    for j in range(i+1,len(nums)):
        total=nums[i]+nums[j]
        if total==target:
            nlist.append(i)
            nlist.append(j)      
print(nlist)
# Out:
# [0, 1]

# %% [markdown]
# ### 🔹 字符串与列表操作
# - **涉及知识**:**str**和**list**的内置函数与方法
# - **常见错误**：
#   - 忘记字符串是不可变的。
#   - 列表浅拷贝/深拷贝混淆。
# - **典型例题**：
#   - 回文问题

# %% [markdown]
# ### 🔹 输入输出与格式化
# - **涉及知识**: `.format()`;`f'{}'`
# - **常见错误**：多输出空格/换行，导致和标准答案不匹配。
# - **典型例题**：电费分段计算（Assignment 2 Q1）。
