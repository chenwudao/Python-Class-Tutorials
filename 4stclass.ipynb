# %% [markdown]
# ### **主动复习梳理一下所学知识，有助于理解掌握！**
# ![python的传递机制](rule.png)
# ---
# #### string、list、dict、tuple、set这些迭代体的方法（有什么？菜鸟编程）
# ![list的内置方法](list.png)
# ---
# #### dict的应用->哈希表（hash table）
# ---
# #### 正则表达式（我也没怎么接触过，应该不会怎么考，这玩意就是要记）
# ![正则表达式](regax.png)
# ---
# ### 高阶函数
# - map()
# - filter()
# - lambda

# %%
def afunction(nums,target):
    dict1 = {}
    for i,num in enumerate(nums):
        complement = target - num
        if complement in dict1:
            return (dict1[complement],i)
        dict1[num] = i
# Out:
# 66
